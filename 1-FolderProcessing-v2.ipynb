# %% [markdown]
# # ECG Folder Processing — v2 (RR-interval anomaly layer)
#
# Reads v1 output (`*_rich_processed_beats.csv`) and adds RR-interval timing analysis.
# Saves results to `*_v2_processed_beats.csv` so v1 is never modified.
#
# **New columns added:**
# - `rr_baseline` — rolling median RR of preceding 7 beats (seconds)
# - `rr_flag` — `premature` | `compensatory` | `missed_beat` | `` (empty = normal timing)
# - `rr_burden_pct` — % of premature beats in this 20-s segment
#
# **Comparison colour coding in the viewer:**
# - 🟢 Green dot — v1=normal, v2 timing normal
# - 🟡 Yellow dot — v1=normal **but** v2 flagged as `premature` (v1 missed it)
# - 🔴 Red dot — v1=PVC or VT
# - 🔵 Blue shading — `compensatory` pause zone
# - 🟠 Orange shading — `missed_beat` zone

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from ipywidgets import Button, HBox, Output, Dropdown, HTML
from IPython.display import display, clear_output

sys.path.insert(0, '.')
import ecg_library
from ecg_library.rr_analysis import (
    analyze_rr_anomalies,
    find_missed_beat_candidates,
    find_cross_segment_missed_beats,
)
from ecg_library.pvc_templates import (
    load_template_library, find_morph_candidates, rescore_vt_s_dominant,
)
from ecg_library.filters import filter_signal

DATA_DIR          = 'Data'
FS                = 125
V1_SUFFIX         = '_rich_processed_beats.csv'
V2_SUFFIX         = '_v2_processed_beats.csv'
TEMPLATE_LIB_PATH = 'pvc_templates.npz'
MORPH_THRESHOLD   = 0.80

TEMPLATE_LIB = None
if os.path.exists(TEMPLATE_LIB_PATH):
    TEMPLATE_LIB = load_template_library(TEMPLATE_LIB_PATH)
    meta = TEMPLATE_LIB['meta']
    print(f'Template library loaded: {len(meta)} waveforms  '
          f'({", ".join(f"{l}:{(meta.label==l).sum()}" for l in sorted(meta.label.unique()))})')
else:
    print(f'No template library found at {TEMPLATE_LIB_PATH!r} — morph scoring disabled.')

print('ecg_library loaded.')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Template library loaded: 99 waveforms  (PVC:69, VT:30)
# ecg_library loaded.

# %% [markdown]
# ## 1. Process sessions — add RR analysis on top of v1 output

# %%
v1_files = glob.glob(os.path.join(DATA_DIR, '**', f'*{V1_SUFFIX}'), recursive=True)
print(f'Found {len(v1_files)} v1 session(s).')

for v1_path in sorted(v1_files):
    session_dir = os.path.dirname(v1_path)
    subfolder   = os.path.basename(session_dir)
    v2_path     = os.path.join(session_dir, f'{subfolder}{V2_SUFFIX}')

    if os.path.exists(v2_path):
        print(f'  [skip] {subfolder}')
        continue

    print(f'  [processing] {subfolder} ...', end=' ', flush=True)
    try:
        df = pd.read_csv(v1_path)
        df_v2 = analyze_rr_anomalies(df)
        df_v2.to_csv(v2_path, index=False)
        n_premature = (df_v2['rr_flag'] == 'premature').sum()
        n_missed    = (df_v2['rr_flag'] == 'missed_beat').sum()
        print(f'done  ({n_premature} premature, {n_missed} missed_beat)')
    except Exception as e:
        print(f'ERROR: {e}')

print('\nAll sessions processed.')
# Out:
# Found 253 v1 session(s).
#   [skip] Activity_on_20240810_153545_by_Etienne_5010176_94DEB87F66D7_RAWECG
#   [skip] Activity_on_20250407_093433_by_Etienne_5010176_8CF6812E7FAF_RAWECG
#   [skip] Activity_on_20250602_105602_by_Etienne_5010176_8CF6812E7FAF_RAWECG
#   [skip] Activity_on_20250602_161704_by_Etienne_5010176_8CF6812E7FAF_RAWECG
#   [skip] Activity_on_20250612_064418_by_Etienne_5010176_8CF6812E7FAF_RAWECG
#   [skip] Activity_on_20250612_092844_by_Etienne_5010176_8CF6812E7FAF_RAWECG
#   [skip] Activity_on_20250612_163934_by_Etienne_5010176_8CF6812E7FAF_RAWECG
#   [skip] Activity_on_20250613_064323_by_Etienne_5010176_8CF6812E7FAF_RAWECG
#   [skip] Activity_on_20250613_103713_by_Etienne_5010176_8CF6812E7FAF_RAWECG
#   [skip] Activity_on_20250616_093459_by_Etienne_5010176_8CF6812E7FAF_RAWECG
#   [skip] Activity_on_20250616_154615_by_Etienne_5010176_8CF6812E7FAF_RAWECG
#   [skip] Activity_on_20250617_092819_by_Etienne_5010176_8CF6812E7FAF_RAWECG
# ...

# %% [markdown]
# ## 2. Compare v1 vs v2 — interactive segment viewer

# %%
# ── session selector ──────────────────────────────────────────────────────────
v2_files   = sorted(glob.glob(os.path.join(DATA_DIR, '**', f'*{V2_SUFFIX}'), recursive=True))
subfolders = [os.path.basename(os.path.dirname(p)) for p in v2_files]

if not subfolders:
    print('No v2 files found — run the processing cell above first.')
else:
    default = next((s for s in subfolders if 'IndoorCycling' in s), subfolders[0])

    session_dd = Dropdown(options=subfolders, value=default, description='Session:')
    out        = Output()

    state = {'df': None, 'files': [], 'idx': 0,
             'within_cands': None, 'cross_cands': None, 'morph_cands': None}

    def _numeric_key(fname):
        return int(''.join(filter(str.isdigit, fname.split('.')[0])))

    def load_session(subfolder):
        v2_path     = os.path.join(DATA_DIR, subfolder, f'{subfolder}{V2_SUFFIX}')
        session_dir = os.path.join(DATA_DIR, subfolder)
        df          = pd.read_csv(v2_path)

        # Correct VT beats where v1 detected the S-wave trough instead of the R-peak
        # (S-dominant QRS: small positive R followed immediately by large negative S).
        # Only modifies in-memory; the v2 CSV on disk is unchanged.
        if TEMPLATE_LIB is not None:
            df = rescore_vt_s_dominant(df, session_dir, library=TEMPLATE_LIB,
                                       morph_threshold=MORPH_THRESHOLD, fs=FS)

        files       = sorted(df['filename'].unique(), key=_numeric_key)
        files       = [f for f in files if f != 'ecg_0.csv']

        within = find_missed_beat_candidates(df, session_dir,
                                             library=TEMPLATE_LIB, fs=FS)
        cross  = find_cross_segment_missed_beats(df, session_dir,
                                                 library=TEMPLATE_LIB, fs=FS)

        morph = pd.DataFrame()
        if TEMPLATE_LIB is not None:
            morph = find_morph_candidates(df, session_dir, TEMPLATE_LIB,
                                          threshold=MORPH_THRESHOLD, fs=FS)

        state['df']           = df
        state['files']        = files
        state['idx']          = 0
        state['within_cands'] = within
        state['cross_cands']  = cross
        state['morph_cands']  = morph

    def load_ecg(subfolder, fname):
        path = os.path.join(DATA_DIR, subfolder, fname)
        raw  = pd.read_csv(path, header=None, comment='#')[0].values.astype(float)
        return filter_signal(raw, FS)

    def _missed_beat_color(ctype):
        return {'PVC': 'magenta', 'VT': 'darkorchid'}.get(ctype, 'grey')

    def _plot_gap_candidate(ax, cand_t, cand_amp, ctype, corr, label_suffix='gap'):
        """Render a single missed-beat / gap candidate marker."""
        if ctype in ('PVC', 'VT'):
            mk_color = _missed_beat_color(ctype)
            corr_str = f' {corr:.2f}' if pd.notna(corr) else ''
            ax.plot(cand_t, cand_amp, '^', color=mk_color, ms=10, zorder=6)
            ax.annotate(f'?{ctype}({label_suffix}){corr_str}',
                        (cand_t, cand_amp + 30),
                        color=mk_color, fontsize=8, zorder=7)
        elif ctype == 'normal':
            ax.plot(cand_t, cand_amp, '^', color='steelblue', ms=9, zorder=6,
                    markerfacecolor='none', markeredgewidth=1.5)
            ax.annotate(f'?normal({label_suffix})',
                        (cand_t, cand_amp + 30),
                        color='steelblue', fontsize=8, zorder=7)
        else:  # 'weak' or unknown
            ax.plot(cand_t, cand_amp, 'x', color='grey', ms=8, mew=1.5, zorder=6)
            ax.annotate('?weak', (cand_t, cand_amp + 30),
                        color='grey', fontsize=7, zorder=7)

    def plot_segment():
        with out:
            clear_output(wait=True)
            subfolder = session_dd.value
            df        = state['df']
            files     = state['files']
            idx       = state['idx']

            if not files:
                print('No segments found.')
                return

            fname  = files[idx]
            seg_df = df[df['filename'] == fname].copy()
            sig    = load_ecg(subfolder, fname)
            t      = np.arange(len(sig)) / FS

            def _filter(cands):
                if cands is not None and len(cands):
                    return cands[cands['filename'] == fname]
                return pd.DataFrame()

            within_here = _filter(state['within_cands'])
            cross_here  = _filter(state['cross_cands'])
            morph_here  = _filter(state['morph_cands'])

            n_v1_anom   = (seg_df['beat_type'].isin(['PVC', 'VT'])).sum()
            n_premature = (seg_df['rr_flag'] == 'premature').sum()
            n_v2_new    = ((seg_df['rr_flag'] == 'premature') &
                           (~seg_df['beat_type'].isin(['PVC', 'VT']))).sum()
            burden      = seg_df['rr_burden_pct'].iloc[0] if len(seg_df) > 0 else 0.0
            n_within_mb = len(within_here)
            n_cross_mb  = len(cross_here)
            n_morph     = len(morph_here)

            fig, (ax_ecg, ax_rr) = plt.subplots(
                2, 1, figsize=(16, 7),
                gridspec_kw={'height_ratios': [3, 1]},
                sharex=True,
            )

            ax_ecg.plot(t, sig, 'k-', lw=0.7, zorder=1)

            # Cross-segment missed-beat zone and candidates
            for _, crow in cross_here.iterrows():
                first_beat_t = seg_df.iloc[0]['r_index'] % 2500 / FS if len(seg_df) else 0
                ax_ecg.axvspan(0, first_beat_t, color='orange', alpha=0.18, zorder=0)
                if crow.get('candidate_file', fname) == fname:
                    cand_t   = crow['candidate_r'] / FS
                    cand_amp = min(float(crow['candidate_amp']), 950)
                    _plot_gap_candidate(ax_ecg, cand_t, cand_amp,
                                        crow['candidate_type'],
                                        crow.get('morph_corr', float('nan')))

            # Within-segment beat markers and missed-beat zones
            for _, beat in seg_df.iterrows():
                r_local = int(beat['r_index']) % 2500
                r_t     = r_local / FS
                r_amp   = beat['r_amplitude']
                flag    = beat['rr_flag'] if pd.notna(beat['rr_flag']) else ''
                btype   = beat['beat_type']

                if flag == 'compensatory' and pd.notna(beat['rr_baseline']):
                    zone_start = r_t - float(beat['rr_interval'])
                    ax_ecg.axvspan(max(zone_start, 0), r_t,
                                   color='steelblue', alpha=0.12, zorder=0)
                elif flag == 'missed_beat':
                    zone_start = r_t - float(beat['rr_interval'])
                    ax_ecg.axvspan(max(zone_start, 0), r_t,
                                   color='orange', alpha=0.18, zorder=0)

                plot_amp = min(float(r_amp), 950)
                if btype in ('PVC', 'VT'):
                    color, marker, zorder = 'red', 'o', 4
                    ax_ecg.annotate(btype, (r_t, plot_amp + 30),
                                    color='red', fontsize=9, fontweight='bold', zorder=5)
                elif flag == 'premature':
                    color, marker, zorder = 'gold', 'D', 4
                    ax_ecg.annotate('?premature', (r_t, plot_amp + 30),
                                    color='goldenrod', fontsize=8, zorder=5)
                else:
                    color, marker, zorder = 'limegreen', 'o', 3

                ax_ecg.plot(r_t, plot_amp, marker=marker, color=color,
                            ms=6, zorder=zorder)

            # Within-segment missed-beat candidates
            for _, crow in within_here.iterrows():
                cand_t   = crow['candidate_r'] / FS
                cand_amp = min(float(crow['candidate_amp']), 950)
                _plot_gap_candidate(ax_ecg, cand_t, cand_amp,
                                    crow['candidate_type'],
                                    crow.get('morph_corr', float('nan')))

            # Normal beats v1 labelled normal but match PVC/VT template
            for _, mrow in morph_here.iterrows():
                r_local  = int(mrow['r_index']) % 2500
                mr_t     = r_local / FS
                mr_amp   = min(float(mrow['r_amplitude']), 950)
                lbl_str  = mrow['best_label']
                mk_color = 'magenta' if lbl_str == 'PVC' else 'darkorchid'
                ax_ecg.plot(mr_t, mr_amp, '^', color=mk_color, ms=9, zorder=5,
                            markerfacecolor='none', markeredgewidth=2)
                ax_ecg.annotate(f'?{lbl_str}(mislabelled) {mrow["best_corr"]:.2f}',
                                (mr_t, mr_amp + 30),
                                color=mk_color, fontsize=8, zorder=6)

            ax_ecg.set_ylabel('Amplitude')
            ax_ecg.set_title(
                f'{subfolder}  |  {fname}  ({idx+1}/{len(files)})\n'
                f'v1: {n_v1_anom} PVC/VT    '
                f'v2 new (timing only): {n_v2_new}    '
                f'Burden: {burden:.1f}%    '
                f'Missed-beat candidates: {n_within_mb} within + {n_cross_mb} cross-seg    '
                f'Morph candidates (mislabelled): {n_morph}',
                fontsize=10,
            )
            ax_ecg.grid(True, alpha=0.25)

            # ── RR interval strip ─────────────────────────────────────────────
            rr_vals      = pd.to_numeric(seg_df['rr_interval'],  errors='coerce').values
            rr_base_vals = pd.to_numeric(seg_df['rr_baseline'],  errors='coerce').values
            r_times      = [(int(r) % 2500) / FS for r in seg_df['r_index']]
            flags_arr    = seg_df['rr_flag'].fillna('').values

            ax_rr.plot(r_times, rr_vals, 'k.-', lw=0.8, ms=4, label='RR interval')
            ax_rr.plot(r_times, rr_base_vals, 'b--', lw=1, alpha=0.6, label='Baseline (rolling median)')

            for rt, rr, flag in zip(r_times, rr_vals, flags_arr):
                if not np.isfinite(rr):
                    continue
                dot_color = {
                    'premature':    'red',
                    'compensatory': 'steelblue',
                    'missed_beat':  'orange',
                }.get(flag, None)
                if dot_color:
                    ax_rr.plot(rt, rr, 'o', color=dot_color, ms=7, zorder=4)

            ax_rr.set_ylabel('RR (s)')
            ax_rr.set_xlabel('Time (s)')
            ax_rr.legend(fontsize=8, loc='upper right')
            ax_rr.grid(True, alpha=0.25)

            # ── Figure-level legend below both subplots ───────────────────────
            legend_handles = [
                mpatches.Patch(color='limegreen',  label='Normal'),
                mpatches.Patch(color='red',        label='PVC / VT'),
                mpatches.Patch(color='gold',       label='? premature (v2 RR)'),
                mpatches.Patch(color='steelblue',  alpha=0.5, label='Compensatory zone'),
                mpatches.Patch(color='orange',     alpha=0.5, label='Missed-beat zone'),
                plt.Line2D([0], [0], marker='^', color='magenta',    lw=0, ms=8,
                           label=f'?PVC(gap) ≥{MORPH_THRESHOLD:.2f}'),
                plt.Line2D([0], [0], marker='^', color='darkorchid', lw=0, ms=8,
                           label=f'?VT(gap) ≥{MORPH_THRESHOLD:.2f}'),
                plt.Line2D([0], [0], marker='^', color='steelblue',  lw=0, ms=8,
                           markerfacecolor='none', markeredgewidth=1.5,
                           label='?normal(gap) S-dominant'),
                plt.Line2D([0], [0], marker='x', color='grey',       lw=0, ms=7, mew=1.5,
                           label='?weak(gap)'),
                plt.Line2D([0], [0], marker='^', color='magenta',    lw=0, ms=8,
                           markerfacecolor='none', markeredgewidth=2,
                           label=f'?PVC(mislabelled) ≥{MORPH_THRESHOLD:.2f}'),
                plt.Line2D([0], [0], marker='^', color='darkorchid', lw=0, ms=8,
                           markerfacecolor='none', markeredgewidth=2,
                           label=f'?VT(mislabelled) ≥{MORPH_THRESHOLD:.2f}'),
            ]
            fig.legend(handles=legend_handles, loc='lower center',
                       bbox_to_anchor=(0.5, 0), ncol=6, fontsize=7,
                       framealpha=0.9)

            plt.tight_layout(rect=[0, 0.07, 1, 1])
            plt.show()

    # ── navigation ────────────────────────────────────────────────────────────
    prev_btn = Button(description='◀ Prev')
    next_btn = Button(description='Next ▶')

    def on_prev(_):
        state['idx'] = max(0, state['idx'] - 1)
        plot_segment()

    def on_next(_):
        state['idx'] = min(len(state['files']) - 1, state['idx'] + 1)
        plot_segment()

    def on_session_change(change):
        load_session(change['new'])
        plot_segment()

    prev_btn.on_click(on_prev)
    next_btn.on_click(on_next)
    session_dd.observe(on_session_change, names='value')

    load_session(default)
    plot_segment()
    display(HBox([prev_btn, next_btn, session_dd]), out)
# Out:
# ...
# Output()

# %% [markdown]
# ## 3. Session-level burden summary

# %%
# Summarise v1 vs v2 anomaly counts across all processed sessions
rows = []
for v2_path in sorted(glob.glob(os.path.join(DATA_DIR, '**', f'*{V2_SUFFIX}'), recursive=True)):
    subfolder = os.path.basename(os.path.dirname(v2_path))
    df = pd.read_csv(v2_path)

    total       = len(df)
    v1_pvc_vt   = df['beat_type'].isin(['PVC', 'VT']).sum()
    v2_premature= (df['rr_flag'] == 'premature').sum()
    v2_new      = ((df['rr_flag'] == 'premature') & (~df['beat_type'].isin(['PVC','VT']))).sum()
    v2_missed   = (df['rr_flag'] == 'missed_beat').sum()
    v1_burden   = round(v1_pvc_vt / total * 100, 2) if total > 0 else 0
    v2_burden   = round(v2_premature / total * 100, 2) if total > 0 else 0

    rows.append({
        'session':      subfolder,
        'total_beats':  total,
        'v1_PVC_VT':    v1_pvc_vt,
        'v1_burden%':   v1_burden,
        'v2_premature': v2_premature,
        'v2_new_only':  v2_new,
        'v2_missed_beat': v2_missed,
        'v2_burden%':   v2_burden,
    })

summary = pd.DataFrame(rows)
summary = summary.sort_values('v2_burden%', ascending=False).reset_index(drop=True)
pd.set_option('display.max_colwidth', 60)
pd.set_option('display.width', 200)
display(summary)
# Out:
#                                                          session  total_beats  v1_PVC_VT  v1_burden%  v2_premature  v2_new_only  v2_missed_beat  v2_burden%
# 0    Run_on_20240809_081402_by_Etienne_5010176_94DEB87F66D7_R...         4229       1146       27.10          1615          955             249       38.19
# 1    Sleep_on_20250713_162453_by_Etienne_5010176_8CF6812E7FAF...         2293        405       17.66           815          456              32       35.54
# 2    Rest_on_20251104_184045_by_Etienne_5010176_8CF6812E7FAF_...         1538        325       21.13           491          203              10       31.92
# 3    Run_on_20240810_175739_by_Etienne_5010176_94DEB87F66D7_R...        20343       2952       14.51          6216         4580            2345       30.56
# 4    Activity_on_20250613_103713_by_Etienne_5010176_8CF6812E7...        24604       4458       18.12          7403         3368              41       30.09
# ...
